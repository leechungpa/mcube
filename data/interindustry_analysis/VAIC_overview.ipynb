# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'
from matplotlib import pyplot

# %%
vaic_stn = pd.read_excel('부가가치유발계수_표준_업종.xlsx', \
                       sheet_name='산업연관표_표준행렬_부가가치유발계수')
vaic_stn_02 = pd.read_excel('부가가치유발계수_표준_업종.xlsx', \
                       sheet_name='산업연관표_표준행렬_부가가치유발계수_v_02_상품표준화')
vaic_stn
# Out:
#    Unnamed: 0        가구      광학제품      의료기관      레저업소      레저용품      문화취미  \
# 0          가구  0.762328  0.001341  0.001135  0.002238  0.002490  0.004172
# 1        광학제품  0.017039  2.458012  0.010176  0.012660  0.083684  0.022695
# 2        의료기관  0.007339  0.633221  2.164149  0.005618  0.009461  0.009986
# 3        레저업소  0.003981  0.005410  0.002896  1.088370  0.004153  0.003268
# 4        레저용품  0.001154  0.001548  0.002477  0.023370  1.440624  0.024143
# 5        문화취미  0.002258  0.025756  0.002691  0.005499  0.054555  1.769155
# 6        보건위생  0.002342  0.002632  0.014779  0.006942  0.007892  0.011332
# 7        사무통신  0.021614  0.061637  0.021494  0.013908  0.029264  0.022179
# 8        서적문구  0.010408  0.014589  0.023135  0.011733  0.019558  0.030740
# 9       수리서비스  0.002034  0.005616  0.002940  0.003697  0.002548  0.003538
# 10         숙박  0.005312  0.008175  0.010158  0.008955  0.005823  0.008597
# 11       신변잡화  0.001217  0.002025  0.000712  0.001840  0.005312  0.000454
# ...

# %%
vaic_stn_02
# Out:
#    Unnamed: 0        가구      광학제품      의료기관          레저업소      레저용품      문화취미  \
# 0          가구  0.254109  0.000447  0.000378  7.458447e-04  0.000830  0.001391
# 1        광학제품  0.003408  0.491602  0.002035  2.531976e-03  0.016737  0.004539
# 2        의료기관  0.001835  0.158305  0.541037  1.404489e-03  0.002365  0.002497
# 3        레저업소  0.001991  0.002705  0.001448  5.441850e-01  0.002076  0.001634
# 4        레저용품  0.000288  0.000387  0.000619  5.842529e-03  0.360156  0.006036
# 5        문화취미  0.000753  0.008585  0.000897  1.832991e-03  0.018185  0.589718
# 6        보건위생  0.000585  0.000658  0.003695  1.735404e-03  0.001973  0.002833
# 7        사무통신  0.001965  0.005603  0.001954  1.264325e-03  0.002660  0.002016
# 8        서적문구  0.002082  0.002918  0.004627  2.346639e-03  0.003912  0.006148
# 9       수리서비스  0.001017  0.002808  0.001470  1.848297e-03  0.001274  0.001769
# 10         숙박  0.005312  0.008175  0.010158  8.955373e-03  0.005823  0.008597
# ...

# %%
vaic_stn=vaic_stn.set_index('Unnamed: 0')
vaic_stn_02=vaic_stn_02.set_index('Unnamed: 0')

# %%
import seaborn as sns

sns.set(font="AppleGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data=vaic_stn, annot=False, fmt='.2f', \
            linewidths=.5, cmap='Blues')
plt.title('표준 부가가치유발계수 업종별 정리', fontsize=20)
# Out:
# Text(0.5, 1.0, '표준 부가가치유발계수 업종별 정리')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data=vaic_stn_02, annot=False, fmt='.2f', \
            linewidths=.5, cmap='Greens')
plt.title('표준 부가가치유발계수 업종별 정리 상품 표준화', fontsize=20)
# Out:
# Text(0.5, 1.0, '표준 부가가치유발계수 업종별 정리 상품 표준화')

# %%
vaic_stn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  22 non-null     object
#  1   가구          22 non-null     float64
#  2   광학제품        22 non-null     float64
#  3   의료기관        22 non-null     float64
#  4   레저업소        22 non-null     float64
#  5   레저용품        22 non-null     float64
#  6   문화취미        22 non-null     float64
#  7   보건위생        22 non-null     float64
#  8   사무통신        22 non-null     float64
#  9   서적문구        22 non-null     float64
#  10  수리서비스       22 non-null     float64
#  11  숙박          22 non-null     float64
#  12  신변잡화        22 non-null     float64
#  13  연료판매        22 non-null     float64
#  14  유통업         22 non-null     float64
#  15  음료식품        22 non-null     float64
#  16  의류          22 non-null     float64
#  17  요식업         22 non-null     float64
# ...
