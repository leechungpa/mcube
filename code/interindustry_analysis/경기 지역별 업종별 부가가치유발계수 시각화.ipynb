# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'
from matplotlib import pyplot

# %% [markdown]
# # 경기지역화폐 지역별 부가가치유발계수가 가장 높은 업종

# %%
vaic_local_stn = pd.read_csv \
('../../data/interindustry_analysis/경기_지역별_업종별_부가가치유발계수_표준화.csv')

# %%
vaic_local_stn.
# Out:
#    Unnamed: 0        가구      광학제품      의료기관      레저업소      레저용품      문화취미  \
# 0          가평  0.037116  0.247870  0.199518  0.135146  0.190854  0.197365
# 1          고양  0.122386  0.698588  0.522321  0.270998  0.333772  0.417884
# 2          과천  0.030028  0.345949  0.379135  0.184027  0.142241  0.601343
# 3          광명  0.074531  0.579679  0.571126  0.200778  0.228994  0.475761
# 4          광주  0.230112  0.407452  0.376561  0.182967  0.310153  0.282478
# 5          구리  0.064849  0.486864  0.557580  0.187543  0.348100  0.258144
# 6          군포  0.027044  0.362002  0.715731  0.204587  0.264205  0.247326
# 7         남양주  0.194636  0.409518  0.455968  0.234024  0.384934  0.491411
# 8         동두천  0.051363  0.443727  0.389947  0.145892  0.268294  0.252420
# 9          부천  0.042854  0.473567  0.512343  0.218327  0.277620  0.337761
# 10         수원  0.118210  0.569855  0.557172  0.246987  0.251329  0.351773
# 11         안산  0.155629  0.400092  0.408695  0.178671  0.261854  0.227278
# ...

# %%
vaic_max_biz=vaic_local_stn.idxmax(axis=1)
vaic_max_biz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ae7f6ce6e4f1> in <module>
# ----> 1 vaic_max_biz=vaic_local_stn.idxmax(axis=1)
#       2 vaic_max_biz
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in idxmax(self, axis, skipna)
#    8083         """
#    8084         axis = self._get_axis_number(axis)
# -> 8085         indices = nanops.nanargmax(self.values, axis=axis, skipna=skipna)
#    8086         index = self._get_axis(axis)
#    8087         result = [index[i] if i >= 0 else np.nan for i in indices]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      62             if any(self.check(obj) for obj in obj_iter):
#      63                 f_name = f.__name__.replace("nan", "")
# ---> 64                 raise TypeError(
# ...
