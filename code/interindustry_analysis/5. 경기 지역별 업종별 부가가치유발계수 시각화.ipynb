# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'
from matplotlib import pyplot

# %% [markdown]
# # 경기지역화폐 지역별 부가가치유발계수가 가장 높은 업종

# %%
vaic_local_stn = pd.read_csv \
('../../data/interindustry_analysis/경기_지역별_업종별_부가가치유발계수_표준화.csv')

# %%
vaic_local_stn=vaic_local_stn.set_index('Unnamed: 0')

# %%
vaic_max_biz=DataFrame(vaic_local_stn.idxmax(axis=1))
vaic_max_biz.info()
vaic_max_biz
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 가평 to 화성
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       24 non-null     object
# dtypes: object(1)
# memory usage: 384.0+ bytes
#                0
# Unnamed: 0
# 가평          음료식품
# 고양          사무통신
# 과천          사무통신
# 광명          음료식품
# 광주           유통업
# 구리          음료식품
# 군포          사무통신
# 남양주          유통업
# 동두천          유통업
# 부천           유통업
# 수원           유통업
# 안산          사무통신
# 안성          연료판매
# 양주           유통업
# 양평          연료판매
# 여주           유통업
# 연천          음료식품
# 오산           유통업
# 용인           유통업
# 의정부         사무통신
# 이천           유통업
# 파주           유통업
# 하남           유통업
# 화성          음료식품

# %% [markdown]
# # 지도 시각화

# %%
vaic_max_biz[0].unique()
# Out:
# array(['음료식품', '사무통신', '유통업', '연료판매'], dtype=object)

# %%
from bs4 import BeautifulSoup
from IPython.display import SVG

# %%
image = None
with open('../../data/interindustry_analysis/Gyeonggi_Municipal.svg', \
          'r', encoding='utf-8') as f:
    image = f.read()
    
SVG(image)
#image

# %%
soup = BeautifulSoup(image)
paths = soup.select('path[id]')
paths
# Out:
# [<path d="M 0.19499999,184.46878" id="path300" inkscape:connector-curvature="0" stroke-miterlimit="10" style="fill:none;stroke:#949584;stroke-width:0.38999999;stroke-miterlimit:10"></path>,
#  <path d="M 0.81899999,187.58878" id="path302" inkscape:connector-curvature="0" stroke-miterlimit="10" style="fill:none;stroke:#949584;stroke-width:0.38999999;stroke-miterlimit:10"></path>,
# ...

# %%
image02 = None
with open('../../data/interindustry_analysis/Map_Gyeongi-do.svg', \
          'r', encoding='utf-8') as f:
    image02 = f.read()
    
SVG(image02)

# %%
soup = BeautifulSoup(image02)
paths = soup.select('path[id]')
paths
#glist = soup.select("svg > g[id], svg > path[id]")
# Out:
# [<path d="M 3.7164746e-6,-4.7509589e-7 3.7164746e-6,-278 176.81226,-278 l 176.81226,0 0,277.99999952490412 L 353.62452,278 176.81226,278 3.7164746e-6,278 l 0,-278.00000047509587 z" id="path3783" inkscape:connector-curvature="0" style="fill:#c6ecff;fill-opacity:1;stroke:none"></path>,
#  <path d="m 330.58481,-0.23689527 0,-277.99999473 134.43969,0 134.4397,0 0,277.99999473 0,278.00000527 -134.4397,0 -134.43969,0 0,-278.00000527 z" id="path3836" inkscape:connector-curvature="0" style="fill:#f0f0f0;fill-opacity:1;stroke:none"></path>,
# ...

# %%
colors = ['#eaeceb', '#bfbfbf', '#b2e1ff', '#15a8de']
#'#118ac9'
colors
# Out:
# ['#eaeceb', '#bfbfbf', '#b2e1ff', '#15a8de']

# %%
for item in glist:
    if item['id'] not in vaic_max_biz.index:
        continue
        
        biz=vaic_max_biz[item['id'], '업종']
        
        if biz == '음료식품': color_index = 0
        if biz == '사무통신': color_index = 1
        if biz == '유통업' : color_index = 2
        if biz == '연료판매': color_index = 3
        
        
vaic_max_img = soup.prettify()
SVG(vaic_max_img)

# %%
#path가 안불러와짐
