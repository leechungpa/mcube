# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'
from matplotlib import pyplot

from bs4 import BeautifulSoup
from IPython.display import SVG

# %% [markdown]
# # 경기지역화폐 지역별 부가가치유발계수가 가장 높은 업종

# %%
vaic_local_stn = pd.read_csv \
('../../data/interindustry_analysis/경기_지역별_업종별_부가가치유발계수_표준화.csv')

# %%
vaic_local_stn=vaic_local_stn.set_index('Unnamed: 0')

# %%
vaic_max_biz=DataFrame(vaic_local_stn.idxmax(axis=1))
vaic_max_biz.info()
vaic_max_biz
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 가평 to 화성
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       24 non-null     object
# dtypes: object(1)
# memory usage: 384.0+ bytes
#                0
# Unnamed: 0
# 가평          음료식품
# 고양          사무통신
# 과천          사무통신
# 광명          음료식품
# 광주           유통업
# 구리          음료식품
# 군포          사무통신
# 남양주          유통업
# 동두천          유통업
# 부천           유통업
# 수원           유통업
# 안산          사무통신
# 안성          연료판매
# 양주           유통업
# 양평          연료판매
# 여주           유통업
# 연천          음료식품
# 오산           유통업
# 용인           유통업
# 의정부         사무통신
# 이천           유통업
# 파주           유통업
# 하남           유통업
# 화성          음료식품

# %%
#vaic_max_biz.to_csv \
#('../../data/interindustry_analysis/경기_지역별_업종별_부가가치유발계수_표준화_4개지역_최댓값업종명.csv')

# %% [markdown]
# # 클러스터링 결과에 따른 4개지역
#
# ### ('노원구', '서울특별시')와 가장 유사한 지역 ==> ('광명시', '경기도')
# ### ('중구', '서울특별시')와 가장 유사한 지역 ==> ('구리시', '경기도')
# ### ('수성구', '대구광역시')와 가장 유사한 지역 ==> ('의정부시', '경기도')
# ### ('중구', '대구광역시')와 가장 유사한 지역 ==> ('과천시', '경기도')

# %%
vaic_local_stn
# Out:
#                   가구      광학제품      의료기관      레저업소      레저용품      문화취미  \
# Unnamed: 0
# 가평          0.037116  0.247870  0.199518  0.135146  0.190854  0.197365
# 고양          0.122386  0.698588  0.522321  0.270998  0.333772  0.417884
# 과천          0.030028  0.345949  0.379135  0.184027  0.142241  0.601343
# 광명          0.074531  0.579679  0.571126  0.200778  0.228994  0.475761
# 광주          0.230112  0.407452  0.376561  0.182967  0.310153  0.282478
# 구리          0.064849  0.486864  0.557580  0.187543  0.348100  0.258144
# 군포          0.027044  0.362002  0.715731  0.204587  0.264205  0.247326
# 남양주         0.194636  0.409518  0.455968  0.234024  0.384934  0.491411
# 동두천         0.051363  0.443727  0.389947  0.145892  0.268294  0.252420
# 부천          0.042854  0.473567  0.512343  0.218327  0.277620  0.337761
# 수원          0.118210  0.569855  0.557172  0.246987  0.251329  0.351773
# 안산          0.155629  0.400092  0.408695  0.178671  0.261854  0.227278
# 안성          0.059990  0.286845  0.357248  0.146392  0.263766  0.216343
# 양주          0.072341  0.485482  0.567230  0.252035  0.246579  0.532425
# 양평          0.034639  0.303032  0.396347  0.105841  0.378391  0.423418
# 여주          0.076350  0.380754  0.428542  0.160063  0.554544  0.595968
# 연천          0.026938  0.367431  0.348831  0.160904  0.697104  0.435914
# 오산          0.076156  0.321956  0.470808  0.191505  0.375847  0.299109
# 용인          0.112836  0.493274  0.817943  0.257683  0.377394  0.349298
# 의정부         0.050291  0.556865  0.527217  0.229498  0.257844  0.308830
# 이천          0.078287  0.457339  0.545887  0.197423  0.326895  0.524221
# 양평          0.652883  0.271299  0.379400  0.111442  0.000027  0.481761
# 여주          0.825818  0.392984  0.414130  0.082584  0.031688  0.111717
# 연천          1.000000  0.181180  0.480916  0.138604  0.009148  0.125005
# 오산          0.912734  0.296316  0.391461  0.083903  0.039551  0.222989
# 용인          0.845381  0.281402  0.418821  0.099127  0.074478  0.170058
# 의정부         0.871710  0.423077  0.403042  0.066460  0.054010  0.136105
# 이천          0.899675  0.375778  0.393539  0.076809  0.078499  0.143256
# 파주          0.898313  0.281529  0.437791  0.085468  0.043287  0.169513
# 하남          0.771601  0.370796  0.370628  0.086154  0.010483  0.088352
# 화성          1.000000  0.329029  0.446828  0.092735  0.054081  0.161901
#
#                 주방용구        직물
# Unnamed: 0
# 가평          0.024607  0.205084
# 고양          0.029750  0.115691
# 과천          0.027713  0.213014
# 광명          0.092475  0.468040
# 광주          0.073850  0.438560
# 구리          0.051195  0.402305
# 군포          0.050543  0.236199
# 남양주         0.067686  0.404485
# 동두천         0.072011  0.506787
# 부천          0.070304  0.386585
# 수원          0.066337  0.426103
# 안산          0.062081  0.524331
# 안성          0.176540  0.275379
# 양주          0.164453  0.438499
# 양평          0.063892  0.255276
# 여주          0.184599  0.496534
# 연천          0.162280  0.327478
# 오산          0.080346  0.379208
# 용인          0.056416  0.341371
# 의정부         0.058242  0.443182
# 이천          0.131249  0.466102
# 파주          0.059834  0.459110
# 하남          0.088140  0.580543
# 화성          0.047423  0.359844
#
# [24 rows x 22 columns]

# %%
vaic_stn_t4=vaic_local_stn.transpose()[['구리','광명','과천','의정부']]
vaic_stn_t4
# Out:
# Unnamed: 0        구리        광명        과천       의정부
# 가구          0.064849  0.074531  0.030028  0.050291
# 광학제품        0.486864  0.579679  0.345949  0.556865
# 의료기관        0.557580  0.571126  0.379135  0.527217
# 레저업소        0.187543  0.200778  0.184027  0.229498
# 레저용품        0.348100  0.228994  0.142241  0.257844
# 문화취미        0.258144  0.475761  0.601343  0.308830
# 보건위생        0.448422  0.517169  0.292677  0.458129
# 사무통신        0.759021  0.741590  1.000000  1.000000
# 서적문구        0.297762  0.352352  0.487626  0.322311
# 수리서비스       0.166681  0.209179  0.151857  0.204110
# 숙박          0.066347  0.131917  0.020876  0.104335
# 신변잡화        0.101242  0.125578  0.073862  0.115426
# 연료판매        0.105780  0.207979  0.096841  0.183503
# 유통업         0.974329  0.994314  0.690122  0.980603
# 음료식품        1.000000  1.000000  0.478861  0.871710
# 의류          0.438444  0.318051  0.280711  0.423077
# 요식업         0.378930  0.391687  0.269776  0.403042
# 자동차정비       0.068333  0.061297  0.029026  0.066460
# 자동차판매       0.049992  0.079008  0.000018  0.054010
# 전기가전        0.147330  0.156004  0.035704  0.136105
# 주방용구        0.051195  0.092475  0.027713  0.058242
# 직물          0.402305  0.468040  0.213014  0.443182

# %%
#vaic_stn_t4.to_csv \
#('../../data/interindustry_analysis/경기_지역별_업종별_부가가치유발계수_표준화_4개지역.csv')

# %%
vaic_stn_t4.transpose().plot(kind='barh',figsize=(15,15))

# %%
vaic_stn_t4.transpose().plot.barh(stacked=True, figsize=(15,8));

# %%
from IPython.display import Image

Image('../../data/interindustry_analysis/graph/경기도 4개지역 부가가치유발계수 표준화.png')
