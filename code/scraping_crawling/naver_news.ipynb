# %%
#-*- coding: utf-8 -*-
import os
import sys
import urllib.request
import requests
import pandas as pd

client_id = "E0HOXFSgmHw4OXSXrF6C"
client_secret = "dQk3jXQuHo"
# encText = urllib.parse.quote("코로나")
# search/(news, blog)
# url = "https://openapi.naver.com/v1/search/news?query=" + encText # json 결과'

# %%
search_word = '코로나' #검색어
encode_type = 'json' #출력 방식 json 또는 xml
max_display = 100 #출력 뉴스 수 10~100
sort = 'date' #결과값의 정렬기준 시간순 date, 관련도 순 sim
 # 출력 위치 1~1000

#url = f"https://openapi.naver.com/v1/search/news.{encode_type}?query={search_word}&display={str(int(max_display))}&start={str(int(start))}&sort={sort}"

# %%
headers = {'X-Naver-Client-Id' : client_id,
           'X-Naver-Client-Secret':client_secret
           }

# %%
naver_news = pd.DataFrame()
for start in range(1,1000):
    url = f"https://openapi.naver.com/v1/search/news.{encode_type}?query={search_word}&display={str(int(max_display))}&start={str(int(start))}&sort={sort}"
    r = requests.get(url, headers=headers)
    naver_news = pd.concat([naver_news, pd.DataFrame(r.json()['items'])])

# %%
naver_news.shape
# Out:
# (99900, 5)

# %%
def clean_html(x):
    x = re.sub("\&\w*\;","",x)
    x = re.sub("<.*?>","",x)
    return x++9

df['title'] = df['title'].apply(lambda x: clean_html(x))
df['description'] = df['description'].apply(lambda x: clean_html(x))

# %%
naver_news[80155:80189]
# Out:
#                                                 title  \
# 55                          Police Shooting Wisconsin
# 56                      YEMEN CONFLICT HOUTHI FUNERAL
# 57                  [삶의 향기] <b>코로나</b> 광풍 속의 역사 시간 여행
# 58                            MYANMAR JAPAN DIPLOMACY
# 59                 USA GOVERNMENT CONGRESS USPS DEJOY
# 60                          Police Shooting Wisconsin
# 61                      YEMEN CONFLICT HOUTHI FUNERAL
# 62                      YEMEN CONFLICT HOUTHI FUNERAL
# 63                      YEMEN CONFLICT HOUTHI FUNERAL
# 64                      YEMEN CONFLICT HOUTHI FUNERAL
# 65                          Police Shooting Wisconsin
# 66                          Police Shooting Wisconsin
# 67       [최병일의 이코노믹스] 중국이 ‘만리방화벽’ 쌓아올리자 미국도 맞대응 본격...
# 68                            MYANMAR JAPAN DIPLOMACY
# 69                      YEMEN CONFLICT HOUTHI FUNERAL
# 70  <b>코로나</b> 재창궐속 주도주?...LG화학·삼성SDI 등 매매 유효, 진원생...
# ...
